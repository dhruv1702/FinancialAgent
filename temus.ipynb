# %%
from edgar import *
import pandas as pd
# Tell the SEC who you are
set_identity("Dhruv Verma dhruvy1702@gmail.com")
#filings = get_filings(form=["10-K", "10-Q"],year=range(2020, 2023))
# Out:
# INFO:rich:Identity of the Edgar REST client set to [Dhruv Verma dhruvy1702@gmail.com]

# %%
filings = get_filings(form=["10-K", "10-Q"],year=range(2020, 2023))
filings
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────────── Filings ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │        form     company                                  cik       filing_date   accession_number               │
# │  ─────────────────────────────────────────────────────────────────────────────────────────────────────          │
# ...

# %%
df = filings.to_pandas()

# %%
filing = filings[0]
filing
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────── Jupiter Wellness Acquisition Corp. [1883799] 10-K 📊 ──────────────────────────────╮
# │ ╭──────────────────────┬────────────╮                                                                           │
# │ │ 0001493152-22-037163 │ 2022-12-30 │                                                                           │
# │ ╰──────────────────────┴────────────╯                                                                           │
# │ ╭────────────────────────────────────────────────────────────────────────────────────────────╮                  │
# │ │ Links: 🏠 Homepage 📄 Primary Document 📜 Full Submission Text                             │                  │
# │ ├────────────────────────────────────────────────────────────────────────────────────────────┤                  │
# ...

# %%
filings = Company("META").get_filings(form=['10-K', '10-Q'])

# %%
filings
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭────────────────────────────────── Filings for Meta Platforms, Inc. [1326801] ───────────────────────────────────╮
# │                                                                                                                 │
# │        form   filed        accession_number       xbrl                                                          │
# │  ──────────────────────────────────────────────────────                                                         │
# │   0    10-Q   2024-04-25   0001326801-24-000049   ✓                                                             │
# │   1    10-K   2024-02-02   0001326801-24-000012   ✓                                                             │
# │   2    10-Q   2023-10-26   0001326801-23-000103   ✓                                                             │
# ...

# %%
filings = Company('GOOGL').get_filings(form=['10-K','10-Q'])

# %%
filings[1]
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────── Alphabet Inc. [1652044] 10-K 📊 ────────────────────────────────────────╮
# │ ╭──────────────────────┬────────────╮                                                                           │
# │ │ 0001652044-24-000022 │ 2024-01-31 │                                                                           │
# │ ╰──────────────────────┴────────────╯                                                                           │
# │ ╭────────────────────────────────────────────────────────────────────────────────────────────╮                  │
# │ │ Links: 🏠 Homepage 📄 Primary Document 📜 Full Submission Text                             │                  │
# │ ├────────────────────────────────────────────────────────────────────────────────────────────┤                  │
# ...

# %%
filing = filings[1]
filing.document
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────┬─────────────┬──────┬────────╮
# │ Document          │ Description │ Type │ Size   │
# ├───────────────────┼─────────────┼──────┼────────┤
# │ goog-20231231.htm │ 10-K        │ 10-K │ 2.3 MB │
# ╰───────────────────┴─────────────┴──────┴────────╯

# %%
filing.report_date
# Out:
# '2023-12-31'

# %%
filing.document.__dict__
# Out:
# {'sequence_number': '1',
#  'description': '10-K',
#  'document': 'emkr-20220930.htm',
#  'ixbrl': True,
#  'path': '/ix?doc=/Archives/edgar/data/808326/000080832622000061/emkr-20220930.htm',
#  'document_type': '10-K',
#  'size': 2003440}

# %%
df
# Out:
#          form                             company      cik filing_date  \
# 0        10-K  Jupiter Wellness Acquisition Corp.  1883799  2022-12-30
# 1        10-K               Kingfish Holding Corp  1374881  2022-12-30
# 2        10-K    NORTH EUROPEAN OIL ROYALTY TRUST    72633  2022-12-30
# 3      10-K/A              DUET Acquisition Corp.  1890671  2022-12-30
# 4      10-K/A            Duckhorn Portfolio, Inc.  1835256  2022-12-30
# ...       ...                                 ...      ...         ...
# 85563    10-Q                 Hubilu Venture Corp  1639068  2020-01-02
# 85564    10-Q                    LANDEC CORP \CA\  1005286  2020-01-02
# 85565    10-Q                Petrolia Energy Corp  1368637  2020-01-02
# 85566    10-Q            RESOURCES CONNECTION INC  1084765  2020-01-02
# 85567  10-Q/A     BIGFOOT PROJECT INVESTMENTS INC  1569568  2020-01-02
#
#            accession_number
# 0      0001493152-22-037163
# 1      0001477932-22-009583
# ...

# %%
from edgar import *

# Set your EDGAR identity
set_identity("Your Name your.email@example.com")

# List of top 100 companies by ticker symbol
#top_100_companies = ["AAPL", "MSFT", "GOOGL", "AMZN", "META"]
# top_50_companies = [
#     "AAPL", "MSFT", "GOOGL", "AMZN", "TSLA", "META", "NVDA", "JPM", "JNJ", "V",
#     "UNH", "HD", "PG", "PYPL", "DIS", "MA", "NFLX", "KO", "PEP", "XOM",
#     "CSCO", "MRK", "INTC", "T", "PFE", "BA", "WMT", "VZ", "ADBE", "CMCSA",
#     "CRM", "ABT", "NKE", "LLY", "ORCL", "TMO", "MCD", "MDT", "NEE", "HON",
#     "PM", "AMGN", "COST", "CVX", "TXN", "AVGO", "DHR", "QCOM", "UPS", "BMY"
# ]
top_50_companies = ['META']
# Function to download filings for the past 10 years
def download_filings_for_companies(companies, form_types):
    for company in companies:
        try:
            filings = Company(company).get_filings(form=form_types)
            filings = filings.filter(date="2013-01-01:2024-01-01")
            for filing in filings:
                filing_markdown = filing.markdown()
                date = filing.filing_date
                if filing.document.document_type=='10-K':
                    fdate= date.year
                    with open(f"data/{company}_{filing.document.description}_{fdate}.md", "w") as f:
                        f.write(filing_markdown)
                elif filing.document.document_type=='10-Q':
                    fdate = (pd.Period(date, freq='Q').strftime('%Y-Q%q'))
                    with open(f"data/{company}_{filing.document.description}_{fdate}.md", "w") as f:
                        f.write(filing_markdown)
        except Exception as e:
            print(f"Error downloading filings for {company}: {e}")

# Download 10-K and 10-Q filings
download_filings_for_companies(top_50_companies, form_types=["10-K", "10-Q"])
# Out:
# INFO:rich:Identity of the Edgar REST client set to [Your Name your.email@example.com]

# %%
import os
files = os.listdir('data/')
len(set([x.split('_')[0] for x in files ]))

# %%
import os
import markdown2
from langchain.text_splitter import MarkdownTextSplitter

# Function to read and chunk markdown files
def chunk_markdown_files(directory):
    chunked_data = {}
    splitter = MarkdownTextSplitter(chunk_size=1500, chunk_overlap=100)
    
    for filename in os.listdir(directory):
        if filename.endswith(".md"):
            with open(os.path.join(directory, filename), 'r') as file:
                markdown_content = file.markdown()
                chunks = splitter.split_text(markdown_content)
                chunked_data[filename] = chunks
    return chunked_data

chunked_data = chunk_markdown_files("data")

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

# Function to read and chunk markdown files
def chunk_markdown_files_r(directory):
    r_chunked_data = {}
    splitter = RecursiveCharacterTextSplitter(chunk_size=1500, chunk_overlap=100)
    
    for filename in os.listdir(directory):
        if filename.endswith(".md"):
            with open(os.path.join(directory, filename), 'r') as file:
                markdown_content = file.read()
                chunks = splitter.split_text(markdown_content)
                chunked_data[filename] = chunks
    return r_chunked_data

r_chunked_data = chunk_markdown_files_r("data")

# %%
r_chunked_data
# Out:
# {}

# %%
r_chunked_data['CMCSA_10-Q_2018-Q3.md'][2]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[141], line 1
# ----> 1 r_chunked_data['CMCSA_10-Q_2018-Q3.md'][2]
#
# KeyError: 'CMCSA_10-Q_2018-Q3.md'

# %%
chunked_data['CMCSA_10-Q_2018-Q3.md'][2]
# Out:
# 'Indicate by check mark whether the registrant (1) has filed all reports required to be filed by Section 13 or 15(d) of the Securities Exchange Act of 1934 during the preceding twelve months (or for such shorter period that the registrant was required to file such reports), and (2) has been subject to such filing requirements for the past 90 days.\n|    |                         |     |    |    |    |\n|---:|:------------------------|:----|:---|:---|:---|\n|  2 | Comcast Corporation     | Yes | x  | No | c  |\n|  3 | NBCUniversal Media, LLC | Yes | x  | No | c  |\nIndicate by check mark whether the registrant has submitted electronically and posted on its corporate website, if any, every Interactive Data File required to be submitted and posted pursuant to Rule 405 of Regulation S-T during the preceding 12 months (or for such period that the registrant was required to submit and post such files).\n|    |                         |     |    |    |    |\n|---:|:------------------------|
# ...

# %%
chunked_data.keys()
# Out:
# dict_keys(['CMCSA_10-Q_2018-Q3.md', 'NKE_10-Q_2014-Q2.md', 'AMGN_10-K_2015.md', 'UNH_10-K_2013.md', 'PYPL_QUARTERLY REPORT_2015-Q4.md', 'AMGN_10-Q_2017-Q3.md', 'UPS_10-Q_2020-Q2.md', 'META_10-Q_2013-Q4.md', 'KO_10-K_2018.md', 'DIS_10-Q_2019-Q2.md', 'MCD_FORM 10-K_2014.md', 'NFLX_FORM 10-K_2013.md', 'NVDA_FY2019 10-K_2019.md', 'QCOM_10-Q_2016-Q3.md', 'T_AT&T 2013 FORM 10-Q_2013-Q2.md', 'MCD_10-Q_2014-Q4.md', 'HON_10-Q_2021-Q2.md', 'NEE_10-K_2013.md', 'JNJ_10-Q 2Q 2016_2016-Q3.md', 'GOOGL_10-Q_2021-Q4.md', 'XOM_FORM 10-Q_2013-Q4.md', 'CRM_10-Q_2020-Q4.md', 'INTC_10-Q_2019-Q4.md', 'VZ_10-Q_2021-Q4.md', 'MCD_FORM 10-K_2020.md', 'CRM_10-Q_2015-Q2.md', 'ADBE_10-Q_2013-Q2.md', 'TSLA_FORM 10-Q_2014-Q4.md', 'MCD_10-Q_2021-Q2.md', 'AMGN_10-K_2021.md', 'AAPL_FORM 10-Q_2013-Q3.md', 'JPM_10-Q_2018-Q4.md', 'UPS_10-Q_2015-Q4.md', 'UNH_10-Q_2022-Q3.md', 'NKE_10-Q_2021-Q4.md', 'PEP_FORM 10-Q_2021-Q4.md', 'NFLX_10-Q_2019-Q2.md', 'QCOM_10-K_2018.md', 'NKE_10-K_2018.md', 'HD_10-Q_2016-Q4.md', 'HD_10-K_2
# ...

# %%
import os
export SUPABASE_URL='https://dmfyezdikbnvkorpyvsd.supabase.co'
export SUPABASE_KEY='eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6ImRtZnllemRpa2JudmtvcnB5dnNkIiwicm9sZSI6ImFub24iLCJpYXQiOjE3MTk3NDk5NDUsImV4cCI6MjAzNTMyNTk0NX0.1vgghGOC6XZjAKQI8jizwhEq_y5oLRODuHKS1tOBUIk'

# %%
url: str = "https://dmfyezdikbnvkorpyvsd.supabase.co"
key: str = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6ImRtZnllemRpa2JudmtvcnB5dnNkIiwicm9sZSI6ImFub24iLCJpYXQiOjE3MTk3NDk5NDUsImV4cCI6MjAzNTMyNTk0NX0.1vgghGOC6XZjAKQI8jizwhEq_y5oLRODuHKS1tOBUIk"

# %%
from supabase import create_client, Client
from sentence_transformers import SentenceTransformer
import numpy as np

# Initialize Supabase client
url: str = "https://dmfyezdikbnvkorpyvsd.supabase.co"
key: str = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6ImRtZnllemRpa2JudmtvcnB5dnNkIiwicm9sZSI6ImFub24iLCJpYXQiOjE3MTk3NDk5NDUsImV4cCI6MjAzNTMyNTk0NX0.1vgghGOC6XZjAKQI8jizwhEq_y5oLRODuHKS1tOBUIk"
supabase: Client = create_client(url, key)

# Load Sentence-Transformers model
#model = SentenceTransformer('all-MiniLM-L6-v2')
embedding_model = SentenceTransformer('Alibaba-NLP/gte-large-en-v1.5', trust_remote_code=True)

# Function to store embeddings in Supabase
def store_embeddings(chunked_data):
    for filename, chunks in chunked_data.items():
        for i, chunk in enumerate(chunks):
            embedding = embedding_model.encode(chunk).tolist()
            data = {
                "filename": filename,
                "chunk_id": i,
                "content": chunk,
                "embedding": embedding
            }
            supabase.table("top50").insert(data).execute()

# Ensure your Supabase table is created with the correct schema
# Example schema:
# CREATE TABLE sec_500 (
#     id serial PRIMARY KEY,
#     filename text,
#     chunk_id int,
#     content text,
#     embedding vector(384)
# );

store_embeddings(chunked_data)
# Out:
# INFO:sentence_transformers.SentenceTransformer:Use pytorch device_name: mps
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: Alibaba-NLP/gte-large-en-v1.5
# ...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[131], line 37
#      25             supabase.table("top50").insert(data).execute()
#      27 # Ensure your Supabase table is created with the correct schema
#      28 # Example schema:
#      29 # CREATE TABLE sec_500 (
#    (...)
#      34 #     embedding vector(384)
#      35 # );
# ---> 37 store_embeddings(chunked_data)
#
# Cell In[131], line 18, in store_embeddings(chunked_data)
#      16 for filename, chunks in chunked_data.items():
#      17     for i, chunk in enumerate(chunks):
# ---> 18         embedding = embedding_model.encode(chunk).tolist()
#      19         data = {
# ...

# %%
def query_embeddings(query):
    query_embedding = embedding_model.encode(query).tolist()
    response = supabase.rpc("match_documents", {"input_embedding": query_embedding}).execute()
    return response.data

# Example RPC function in Supabase to match embeddings
# CREATE OR REPLACE FUNCTION match_documents(embedding vector(768))
# RETURNS TABLE(id int, filename text, chunk_id int, content text, similarity float)
# LANGUAGE plpgsql AS $$
# BEGIN
#     RETURN QUERY
#     SELECT id, filename, chunk_id, content,
#     1 - (embedding <=> sec_500.embedding) AS similarity
#     FROM sec_500
#     ORDER BY sec_500.embedding <=> embedding
#     LIMIT 5;
# END;
# $$;

# %%
from langchain.llms import Ollama
from langchain.chains import RetrievalQA

# Initialize the Ollama model
ollama = Ollama(model='llama3')

# Function to answer questions
def answer_question(query):
    matching_docs = query_embeddings(query)
    context = " ".join([doc['content'] for doc in matching_docs])
    #response = ollama({"context": context, "query": query})
    prompt = f"Context:\n{context}\n\nQuestion: {query}\nAnswer:"
    response = ollama(prompt)
    return response

# Test the function
query = "What is the revenue of Apple in 2018?"
print(answer_question(query))
# Out:
# According to the provided data from Apple's 2018 Form 10-K, the net sales by reportable segment and net sales and unit sales by product are as follows:
#
# | Segment/Product | 2018 (dollars in millions) |
# | --- | --- |
# | iPhone | $142,014 million |
# | Mac | $26,449 million |
# | iPad | $13,016 million |
# | Wearables, Home and Accessories | $10,027 million |
# | Services | $37,050 million |
# | Total | $228,556 million |
#
# Therefore, the revenue of Apple in 2018 was $228,556 million.

# %%
url

# %%
os.environ['SUPABASE_URL'] = url
os.environ['SUPABASE_KEY'] = key

# %% [markdown]
# ## Final

# %%
from dotenv import load_dotenv
import os
import logging
from sentence_transformers import SentenceTransformer
from langchain.text_splitter import MarkdownTextSplitter
from supabase import create_client, Client
from langchain.vectorstores import VectorStore
from langchain.llms import Ollama
from langchain_core.documents import Document

from langchain.chains import create_retrieval_chain
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain_core.prompts import ChatPromptTemplate
import streamlit as st
load_dotenv()
# Out:
# False

# %%
url

# %%
# Set up logging
logging.basicConfig(level=logging.INFO)

# Initialize the text splitter for Markdown
splitter = MarkdownTextSplitter(chunk_size=1000, chunk_overlap=100)

# Initialize Supabase client
url: str = os.getenv("SUPABASE_URL")
key: str = os.getenv("SUPABASE_KEY")
supabase: Client = create_client(url, key)

# Load Sentence-Transformers model
model = SentenceTransformer('all-MiniLM-L6-v2')

# Function to read and chunk markdown files
def chunk_markdown_files(directory):
    chunked_data = {}
    for filename in os.listdir(directory):
        if filename.endswith(".md"):
            with open(os.path.join(directory, filename), 'r') as file:
                markdown_content = file.read()
                chunks = splitter.split_text(markdown_content)
                chunked_data[filename] = chunks
    return chunked_data

# Chunk the markdown files in the data directory
#chunked_data = chunk_markdown_files("data")

# Function to store embeddings in Supabase
def store_embeddings(chunked_data):
    for filename, chunks in chunked_data.items():
        for i, chunk in enumerate(chunks):
            embedding = model.encode(chunk).tolist()
            data = {
                "filename": filename,
                "chunk_id": i,
                "content": chunk,
                "embedding": embedding
            }
            supabase.table("sec_500").insert(data).execute()

#store_embeddings(chunked_data)
# Out:
# INFO:sentence_transformers.SentenceTransformer:Use pytorch device_name: mps
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: all-MiniLM-L6-v2
# /opt/anaconda3/envs/torch_gpu/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
# Define the Supabase Vector Store
class SupabaseVectorStore(VectorStore):
    def __init__(self, client, embedding_model):
        self.client = client
        self.embedding_model = embedding_model

    def add_texts(self, texts, metadatas=None):
        embeddings = self.embedding_model.encode(texts)
        for i, text in enumerate(texts):
            metadata = metadatas[i] if metadatas else {}
            self.client.table("sec_500").insert({
                "content": text,
                "embedding": embeddings[i].tolist(),
                **metadata
            }).execute()

    @classmethod
    def from_texts(cls, texts, embedding_model, metadatas=None, client=None):
        store = cls(client, embedding_model)
        store.add_texts(texts, metadatas)
        return store
    
    def similarity_search(self, query, k=5):
        query_embedding = self.embedding_model.encode(query).tolist()
        response = self.client.rpc("match_documents", {"input_embedding": query_embedding}).execute()
        return [
            Document(page_content=item["content"], metadata={"filename": item["filename"], "chunk_id": item["chunk_id"]})
            for item in response.data[:k]
        ]

vector_store = SupabaseVectorStore(supabase, model)

# Initialize the Ollama model
ollama = Ollama(model='llama3')


system_prompt = (
    "You are an intelligent financial agent specializing in answering questions grounded in 10-K, 10-Q reports of public companies. "
    "Your task is to provide well-reasoned and concise answers. When answering, follow these guidelines:\n\n"
    "1. **Understand the Question**: Clearly understand the user's question before starting your reasoning process.\n"
    "2. **Retrieve Relevant Context**: Use the provided context to support your answer. If no relevant context is found, inform the user.\n"
    "3. **Chain of Thought Reasoning**: Break down your reasoning process into clear, logical steps. Explain your thought process as follows:\n"
    "    a. Identify the key elements of the question.\n"
    "    b. Retrieve and analyze relevant information from the context.\n"
    "    c. Synthesize the information to form a coherent answer.\n"
    "4. **Grounding and Sources**: Always ground your answers in the context provided. Cite specific parts of the documents (filename and chunk ID) to support your response. If an answer is not found in the context, state that clearly and try to provide a reasonable answer based on your knowledge.\n"
    "5. **Conciseness and Clarity**: Keep your answers concise, using a maximum of three sentences. Ensure clarity and avoid ambiguity.\n"
    "6. **Politeness and Professionalism**: Maintain a polite and professional tone in all your responses.\n"
    "7. **Cite Multiple Sources**: Whenever possible, cite multiple sources in your answer.\n\n"
    "If you don't know the answer, say that you don't know. Here is the retrieved context to help you answer the question:\n\n"
    "{context}"
)

# Define the prompt template
prompt = ChatPromptTemplate.from_messages(
    [
        ("system", system_prompt),
        ("human", "{input}"),
    ]
)

# Create the question-answer chain
question_answer_chain = create_stuff_documents_chain(ollama, prompt)
rag_chain = create_retrieval_chain(vector_store.as_retriever(), question_answer_chain)

# Function to answer questions with sources
def answer_question(query):
    response = rag_chain.invoke({"input": query})
    matching_docs = vector_store.similarity_search(query, k=5)
    sources = [(doc.metadata["filename"], doc.metadata["chunk_id"]) for doc in matching_docs]

    #sources = [(doc[1], doc[2]) for doc in matching_docs]
    return response, sources

# # Streamlit Interface
# st.title("Intelligent Financial Agent")

# st.write("""
#     This is an intelligent financial agent. It uses the provided context to answer financial questions grounded in 10K, 10Q reports of public companies. When the answer does not exist in the context, I will try to answer to the best of my ability and declare that it is not found in SEC data.
# """)

# query = st.text_input("Enter your question about financial reports:")

# if query:
#     answer, sources = answer_question(query)
#     st.write(f"Answer: {answer}")
#     st.write("Sources:")
#     for filename, chunk_id in sources:
#         st.write(f"- {filename}, chunk {chunk_id}")

# %%
answer, sources = answer_question(query="what was apple's revenue in 2018?")
# Out:
# Batches: 100%|██████████| 1/1 [00:00<00:00,  4.01it/s]
# INFO:httpx:HTTP Request: POST https://dmfyezdikbnvkorpyvsd.supabase.co/rest/v1/rpc/match_documents "HTTP/1.1 200 OK"
# Batches: 100%|██████████| 1/1 [00:00<00:00, 17.62it/s]
# INFO:httpx:HTTP Request: POST https://dmfyezdikbnvkorpyvsd.supabase.co/rest/v1/rpc/match_documents "HTTP/1.1 200 OK"

# %%
answer
# Out:
# {'input': "what was apple's revenue in 2018?",
#  'context': [Document(page_content='Apple Inc. | Q1 2022 Form 10-Q | 6\n\n\n\n\nNote 2 – Revenue\n\nNet sales disaggregated by significant products and services for the three months ended December 25, 2021 and December 26, 2020 were as follows (in millions):', metadata={'filename': 'AAPL_10-Q_2021-12-25.md', 'chunk_id': 51}),
#   Document(page_content='Apple Inc. | 2020 Form 10-K | 20\n\n\n\n\nProducts and Services Performance\n\nThe following table shows net sales by category for 2020, 2019 and 2018 (dollars in millions):', metadata={'filename': 'AAPL_10-K_2020-09-26.md', 'chunk_id': 164}),
#   Document(page_content='Apple Inc. | 2017 Form 10-K | 22\n\n\n\nSales Data\n\nThe following table shows net sales by operating segment and net sales and unit sales by product for 2017, 2016 and 2015 (dollars in millions and units in thousands):', metadata={'filename': 'AAPL_10-K_2017-09-30.md', 'chunk_id': 199}),
# ...

# %%
answer['answer']
# Out:
# 'Based on the provided context, Apple\'s revenue for 2018 can be found in the "Sales Data" section of the 2018 Form 10-K report. According to that report (Apple Inc. | 2018 Form 10-K | 22), net sales by reportable segment and product for 2018 were as follows:\n\n| Segment/Product | Net Sales (dollars in millions) |\n| --- | --- |\n| iPhone | 142,018 |\n| Mac | 20,411 |\n| iPad | 13,268 |\n| Wearables, Home and Accessories | 10,052 |\n| Services | 35,515 |\n\nThe total revenue for Apple in 2018 was not explicitly stated in this table. However, we can infer that it is the sum of these individual product segments and services revenue. To find the exact figure, I would recommend reviewing the "Products and Services Performance" section of the report or searching for the company\'s publicly disclosed earnings statement for 2018.\n\nPlease note that I am unable to provide an exact answer based solely on this context, as the total revenue for Apple in 2018 is not directly stated.'

# %%
response[1]
# Out:
# [('AAPL_10-Q_2021-12-25.md', 51),
#  ('AAPL_10-K_2020-09-26.md', 164),
#  ('AAPL_10-K_2017-09-30.md', 199),
#  ('AAPL_10-K_2016-09-24.md', 195),
#  ('AAPL_10-K_2018-09-29.md', 191)]
